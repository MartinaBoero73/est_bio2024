# %% [markdown]
# # Estructuras Biomoleculares - Trabajo Final ABP

# %% [markdown]
# A partir del paper "Cryptic inoviruses revealed as pervasive in bacteria and archaea across Earth’s biomes", realizamos un análisis exploratorio de los inovirus hallados dentro del genoma de Campylobacter

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./Datos/Tabla6.xlsx")

# %%
df
# Out:
#        Supplementary Table 6. List of matches between inovirus sequences and IMG CRISPR spacer database.  \
# 0                                       Inovirus sequence
# 1              1000631_contig_1643_11_1000631_contig_1643
# 2              1000631_contig_1643_11_1000631_contig_1643
# 3              1000631_contig_1643_11_1000631_contig_1643
# 4               1000631_contig_3646_5_1000631_contig_3646
# ...                                                   ...
# 121730                                          NC_021862
# 121731                                          NC_021866
# 121732                        WP_014603241_MZND01000077.1
# 121733                        WP_014603241_MZND01000077.1
# 121734                         Y607_10019226_Y607_1001922
#
#                    Unnamed: 1                                    Unnamed: 2  \
# 0       Original (meta)genome                              Inovirus species
# ...

# %%
df_resum = df.iloc[1:100]
df_resum.head(10)
# Out:
#    Supplementary Table 6. List of matches between inovirus sequences and IMG CRISPR spacer database.  \
# 1          1000631_contig_1643_11_1000631_contig_1643
# 2          1000631_contig_1643_11_1000631_contig_1643
# 3          1000631_contig_1643_11_1000631_contig_1643
# 4           1000631_contig_3646_5_1000631_contig_3646
# 5           1000631_contig_3646_5_1000631_contig_3646
# 6           1000631_contig_3646_5_1000631_contig_3646
# 7           1000631_contig_3646_5_1000631_contig_3646
# 8           1000631_contig_3646_5_1000631_contig_3646
# 9           1000631_contig_3646_5_1000631_contig_3646
# 10          1001465_contig_1809_1_1001465_contig_1809
#
#    Unnamed: 1                                    Unnamed: 2  \
# 1     1000631  Sp_1000631_contig_1643_3_1000631_contig_1643
# 2     1000631  Sp_1000631_contig_1643_3_1000631_contig_1643
# 3     1000631  Sp_1000631_contig_1643_3_1000631_contig_1643
# 4     1000631  Sp_1000631_contig_3646_5_1000631_contig_3646
# ...

# %%
datos_campylobacterales = df_resum[df_resum["Unnamed: 9"].str.contains("Campylobacterales", na=False)]

print("Especies de inovirus halladas en campylobacter: ")
datos_campylobacterales["Unnamed: 2"]
# Out:
# Especies de inovirus halladas en campylobacter:
# 19    Sp_1022092_contig_2041_6_1022092_contig_2041
# 24    Sp_1024027_contig_6252_4_1024027_contig_6252
# 25    Sp_1024036_contig_1164_6_1024036_contig_1164
# 26    Sp_1024036_contig_1164_6_1024036_contig_1164
# 27    Sp_1024036_contig_1164_6_1024036_contig_1164
# Name: Unnamed: 2, dtype: object

# %%
print("Secuencias encontradas: ")
datos_campylobacterales["Supplementary Table 6. List of matches between inovirus sequences and IMG CRISPR spacer database."]
# Out:
# Secuencias encontradas:
# 19    1022092_contig_2041_6_1022092_contig_2041
# 24    1024027_contig_6252_4_1024027_contig_6252
# 25    1024036_contig_1164_6_1024036_contig_1164
# 26    1024036_contig_1164_6_1024036_contig_1164
# 27    1024036_contig_1164_6_1024036_contig_1164
# Name: Supplementary Table 6. List of matches between inovirus sequences and IMG CRISPR spacer database., dtype: object
